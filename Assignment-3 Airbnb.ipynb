# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\santy\Documents\itern assign 3(a) airbnb(AutoRecovered).csv",encoding='latin1')

# %%
df
# Out:
#          id                                              name  host_id  \
# 0    2539.0                Clean & Quiet Apt Home By The Park   2787.0
# 1    2595.0                             Skylit Midtown Castle   2845.0
# 2    3831.0                   Cozy Entire Floor Of Brownstone   4869.0
# 3    5022.0  Entire Apt: Spacious Studio/Loft By Central Park   7192.0
# 4    5099.0         Large Cozy 1 Br Apartment In Midtown East   7322.0
# ..      ...                                               ...      ...
# 249     NaN                                               NaN      NaN
# 250     NaN                                               NaN      NaN
# 251     NaN                                               NaN      NaN
# 252     NaN                                               NaN      NaN
# 253     NaN                                               NaN      NaN
#
#        host_name neighbourhood_group neighbourhood  latitude  longitude  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'Unnamed: 16'],
#       dtype='object')

# %%
del df["latitude"]

# %%
df
# Out:
#          id                                              name  host_id  \
# 0    2539.0                Clean & Quiet Apt Home By The Park   2787.0
# 1    2595.0                             Skylit Midtown Castle   2845.0
# 2    3831.0                   Cozy Entire Floor Of Brownstone   4869.0
# 3    5022.0  Entire Apt: Spacious Studio/Loft By Central Park   7192.0
# 4    5099.0         Large Cozy 1 Br Apartment In Midtown East   7322.0
# ..      ...                                               ...      ...
# 249     NaN                                               NaN      NaN
# 250     NaN                                               NaN      NaN
# 251     NaN                                               NaN      NaN
# 252     NaN                                               NaN      NaN
# 253     NaN                                               NaN      NaN
#
#        host_name neighbourhood_group neighbourhood  longitude  \
# ...

# %%
del df["longitude"]

# %%
df
# Out:
#          id                                              name  host_id  \
# 0    2539.0                Clean & Quiet Apt Home By The Park   2787.0
# 1    2595.0                             Skylit Midtown Castle   2845.0
# 2    3831.0                   Cozy Entire Floor Of Brownstone   4869.0
# 3    5022.0  Entire Apt: Spacious Studio/Loft By Central Park   7192.0
# 4    5099.0         Large Cozy 1 Br Apartment In Midtown East   7322.0
# ..      ...                                               ...      ...
# 249     NaN                                               NaN      NaN
# 250     NaN                                               NaN      NaN
# 251     NaN                                               NaN      NaN
# 252     NaN                                               NaN      NaN
# 253     NaN                                               NaN      NaN
#
#        host_name neighbourhood_group neighbourhood        room_type  price  \
# ...

# %%
del df["Unnamed: 16"]

# %%
df
# Out:
#          id                                              name  host_id  \
# 0    2539.0                Clean & Quiet Apt Home By The Park   2787.0
# 1    2595.0                             Skylit Midtown Castle   2845.0
# 2    3831.0                   Cozy Entire Floor Of Brownstone   4869.0
# 3    5022.0  Entire Apt: Spacious Studio/Loft By Central Park   7192.0
# 4    5099.0         Large Cozy 1 Br Apartment In Midtown East   7322.0
# ..      ...                                               ...      ...
# 249     NaN                                               NaN      NaN
# 250     NaN                                               NaN      NaN
# 251     NaN                                               NaN      NaN
# 252     NaN                                               NaN      NaN
# 253     NaN                                               NaN      NaN
#
#        host_name neighbourhood_group neighbourhood        room_type  price  \
# ...

# %%
df.describe()
# Out:
#                  id       host_id       price  minimum_nights  \
# count    242.000000  2.420000e+02  242.000000      242.000000
# mean   31667.024793  1.518822e+05  144.272727        8.479339
# std    17953.882898  4.062905e+05   92.279028       20.365172
# min     2539.000000  2.787000e+03   40.000000        1.000000
# 25%    16430.250000  5.136225e+04   85.000000        2.000000
# 50%    28651.500000  1.023750e+05  125.000000        3.000000
# 75%    46864.000000  1.935678e+05  175.000000        5.000000
# max    62430.000000  6.197784e+06  800.000000      200.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count         242.000000         242.000000                      242.000000
# mean          106.438017           1.091653                        1.752066
# std           100.201324           1.000168                        1.247610
# min             1.000000           0.010000                        1.000000
# ...

# %%
cato=df.dtypes[df.dtypes=="object"].index

# %%
cato
# Out:
# Index(['name', 'host_name', 'neighbourhood_group', 'neighbourhood',
#        'room_type', 'last_review'],
#       dtype='object')

# %%
df[cato].describe()
# Out:
#                                       name host_name neighbourhood_group  \
# count                                  242       242                 242
# unique                                 242       199                   5
# top     Clean & Quiet Apt Home By The Park      Mark           Manhattan
# freq                                     1         6                 119
#
#        neighbourhood        room_type last_review
# count            242              242         242
# unique            55                3         129
# top     Williamsburg  Entire home/apt  22/06/2019
# freq              26              133          13

# %%
df["name"].describe()
# Out:
# count                                    242
# unique                                   242
# top       Clean & Quiet Apt Home By The Park
# freq                                       1
# Name: name, dtype: object

# %%
new_room_type=pd.Categorical(df["room_type"],ordered=True)
new_room_type=new_room_type.rename_categories(["type1","type2","type3"])
new_room_type.describe()
# Out:
#             counts     freqs
# categories
# type1          133  0.523622
# type2          107  0.421260
# type3            2  0.007874
# NaN             12  0.047244

# %%
df.isnull().sum()
# Out:
# id                                12
# name                              12
# host_id                           12
# host_name                         12
# neighbourhood_group               12
# neighbourhood                     12
# room_type                         12
# price                             12
# minimum_nights                    12
# number_of_reviews                 12
# last_review                       12
# reviews_per_month                 12
# calculated_host_listings_count    12
# availability_365                  12
# dtype: int64

# %%
df["id"]=df["id"].replace(np.nan,df["id"].mode()[0])

# %%
df["id"].isnull().sum()
# Out:
# 0

# %%
df.dropna()
# Out:
#           id                                              name   host_id  \
# 0     2539.0                Clean & Quiet Apt Home By The Park    2787.0
# 1     2595.0                             Skylit Midtown Castle    2845.0
# 2     3831.0                   Cozy Entire Floor Of Brownstone    4869.0
# 3     5022.0  Entire Apt: Spacious Studio/Loft By Central Park    7192.0
# 4     5099.0         Large Cozy 1 Br Apartment In Midtown East    7322.0
# ..       ...                                               ...       ...
# 237  61492.0          Exclusive Room With Private Bath In  Les  297769.0
# 238  61509.0               Quiet, Clean Midtown Apt W. Elevato   23619.0
# 239  62095.0                 Bk Sweet Suite W/Kitchen&Fullbath  281764.0
# 240  62427.0               Great East Village Apartment Rental  303882.0
# 241  62430.0                     Brownstone Sundrenched Beauty  197755.0
#
#         host_name neighbourhood_group  neighbourhood        room_type  price  \
# ...

# %%
df.isnull().sum()
# Out:
# id                                 0
# name                              12
# host_id                           12
# host_name                         12
# neighbourhood_group               12
# neighbourhood                     12
# room_type                         12
# price                             12
# minimum_nights                    12
# number_of_reviews                 12
# last_review                       12
# reviews_per_month                 12
# calculated_host_listings_count    12
# availability_365                  12
# dtype: int64

# %%
df
# Out:
#          id                                              name  host_id  \
# 0    2539.0                Clean & Quiet Apt Home By The Park   2787.0
# 1    2595.0                             Skylit Midtown Castle   2845.0
# 2    3831.0                   Cozy Entire Floor Of Brownstone   4869.0
# 3    5022.0  Entire Apt: Spacious Studio/Loft By Central Park   7192.0
# 4    5099.0         Large Cozy 1 Br Apartment In Midtown East   7322.0
# ..      ...                                               ...      ...
# 249  2539.0                                               NaN      NaN
# 250  2539.0                                               NaN      NaN
# 251  2539.0                                               NaN      NaN
# 252  2539.0                                               NaN      NaN
# 253  2539.0                                               NaN      NaN
#
#        host_name neighbourhood_group neighbourhood        room_type  price  \
# ...

# %%
df1=df.dropna()

# %%
df1
# Out:
#           id                                              name   host_id  \
# 0     2539.0                Clean & Quiet Apt Home By The Park    2787.0
# 1     2595.0                             Skylit Midtown Castle    2845.0
# 2     3831.0                   Cozy Entire Floor Of Brownstone    4869.0
# 3     5022.0  Entire Apt: Spacious Studio/Loft By Central Park    7192.0
# 4     5099.0         Large Cozy 1 Br Apartment In Midtown East    7322.0
# ..       ...                                               ...       ...
# 237  61492.0          Exclusive Room With Private Bath In  Les  297769.0
# 238  61509.0               Quiet, Clean Midtown Apt W. Elevato   23619.0
# 239  62095.0                 Bk Sweet Suite W/Kitchen&Fullbath  281764.0
# 240  62427.0               Great East Village Apartment Rental  303882.0
# 241  62430.0                     Brownstone Sundrenched Beauty  197755.0
#
#         host_name neighbourhood_group  neighbourhood        room_type  price  \
# ...

# %%
df1.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
new_room_type=pd.Categorical(df1["room_type"],ordered=True)
new_room_type=new_room_type.rename_categories(["type1","type2","type3"])
new_room_type.describe()
# Out:
#             counts     freqs
# categories
# type1          133  0.549587
# type2          107  0.442149
# type3            2  0.008264

# %%
df1["room_type"]=new_room_type
# Out:
# C:\Users\santy\AppData\Local\Temp\ipykernel_1616\334916834.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["room_type"]=new_room_type

# %%
df1
# Out:
#           id                                              name   host_id  \
# 0     2539.0                Clean & Quiet Apt Home By The Park    2787.0
# 1     2595.0                             Skylit Midtown Castle    2845.0
# 2     3831.0                   Cozy Entire Floor Of Brownstone    4869.0
# 3     5022.0  Entire Apt: Spacious Studio/Loft By Central Park    7192.0
# 4     5099.0         Large Cozy 1 Br Apartment In Midtown East    7322.0
# ..       ...                                               ...       ...
# 237  61492.0          Exclusive Room With Private Bath In  Les  297769.0
# 238  61509.0               Quiet, Clean Midtown Apt W. Elevato   23619.0
# 239  62095.0                 Bk Sweet Suite W/Kitchen&Fullbath  281764.0
# 240  62427.0               Great East Village Apartment Rental  303882.0
# 241  62430.0                     Brownstone Sundrenched Beauty  197755.0
#
#         host_name neighbourhood_group  neighbourhood room_type  price  \
# ...

# %%
new_neighbourhood_group=pd.Categorical(df1["neighbourhood_group"],ordered=True)
new_neighbourhood_group=new_room_type.rename_categories(["group1","group2","group3"])
new_neighbourhood_group.describe()
# Out:
#             counts     freqs
# categories
# group1         133  0.549587
# group2         107  0.442149
# group3           2  0.008264

# %%
df1["neighbourhood_group"]=new_neighbourhood_group
# Out:
# C:\Users\santy\AppData\Local\Temp\ipykernel_1616\3704294998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["neighbourhood_group"]=new_neighbourhood_group

# %%
df1
# Out:
#           id                                              name   host_id  \
# 0     2539.0                Clean & Quiet Apt Home By The Park    2787.0
# 1     2595.0                             Skylit Midtown Castle    2845.0
# 2     3831.0                   Cozy Entire Floor Of Brownstone    4869.0
# 3     5022.0  Entire Apt: Spacious Studio/Loft By Central Park    7192.0
# 4     5099.0         Large Cozy 1 Br Apartment In Midtown East    7322.0
# ..       ...                                               ...       ...
# 237  61492.0          Exclusive Room With Private Bath In  Les  297769.0
# 238  61509.0               Quiet, Clean Midtown Apt W. Elevato   23619.0
# 239  62095.0                 Bk Sweet Suite W/Kitchen&Fullbath  281764.0
# 240  62427.0               Great East Village Apartment Rental  303882.0
# 241  62430.0                     Brownstone Sundrenched Beauty  197755.0
#
#         host_name neighbourhood_group  neighbourhood room_type  price  \
# ...

# %%
import matplotlib.pyplot as plt
x=df1["calculated_host_listings_count"]
y=df1["number_of_reviews"]
plt.scatter(x,y, c="red")
plt.show()

# %%
x=df1["reviews_per_month"]
y=df1["availability_365"]
plt.scatter(x,y, c="red")
plt.show()

# %%
x=df1["room_type"]
y=df1["neighbourhood_group"]
plt.bar(x,y)
plt.title("neighbour vs roomtype")
plt.xlabel('room type')
plt.ylabel('neighbourhood group')
plt.show()

# %%
x=df1["minimum_nights"]
y=df1["availability_365"]
plt.bar(x,y)
plt.title("minimum night avalability")
plt.xlabel('minimum_nights')
plt.ylabel('availability_365')
plt.show()

# %%
plt.boxplot(df1["price"])
plt.show()

# %%
plt.boxplot(df1["minimum_nights"])
plt.show()

# %%
plt.boxplot(df1["calculated_host_listings_count"])
plt.show()

# %%
x=df1["neighbourhood"]
y=df1["price"]
plt.bar(x,y)
plt.title("price per night")
plt.xlabel('neighbourhood')
plt.ylabel('price')
plt.show()
